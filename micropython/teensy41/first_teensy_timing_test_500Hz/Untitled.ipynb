# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import sin, cos, tan, pi

# %%
import saleae

# %%
import importlib

# %%
importlib.reload(saleae)
# Out:
# <module 'saleae' from '/Users/kraussry/git/krauss_misc/saleae.py'>

# %%
ls *.csv
# Out:
# digital.csv

# %%
fn = "digital.csv"

# %%
mytest = saleae.saleae_csv(fn)

# %%
mytest.t
# Out:
# array([-4.41165632, -4.41101172, -4.40901168, ...,  3.07132096,
#         3.07332088,  3.07517632])

# %%
mytest.t
# Out:
# array([-4.41165632, -4.41101172, -4.40901168, ...,  3.07132096,
#         3.07332088,  3.07517632])

# %%
mytest.data
# Out:
# array([[-4.41165632,  1.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-4.41101172,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-4.40901168,  1.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 3.07132096,  1.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 3.07332088,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 3.07517632,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
for col in mytest.data.T:
    plt.figure() 
    plt.step(mytest.t,col,where='post')
    plt.xlim([0.00,0.01])

# %%
mytest.data[:,0]
# Out:
# array([-4.41165632, -4.41101172, -4.40901168, ...,  3.07132096,
#         3.07332088,  3.07517632])

# %%
col0 = mytest.columns[0]

# %%
col0.data.max()
# Out:
# 1.0

# %%
col0.find_change_edges()

# %%
ind0 = np.where(col0.change_edges>0)[0][0]

# %%
ind0
# Out:
# 2192

# %%
col0.change_edges[ind0]
# Out:
# 0.00130864

# %%
col0.change_edges[ind0+1]
# Out:
# 0.00331032

# %% [markdown]
# t = mytest.t

# %%
plt.figure()
plt.step(t,col0.data,where='post')
plt.xlim([-0.01,0.1])
# Out:
# (-0.01, 0.1)

# %%
col1 = mytest.columns[1]

# %%
plt.step(t,col0.data,where='post')
plt.step(t,col1.data,where='post')
plt.xlim([-0.002,0.01])
# Out:
# (-0.002, 0.01)

# %%
col2 = mytest.columns[2]

# %%
plt.step(t,col0.data,where='post')
plt.step(t,col2.data,where='post')
plt.xlim([-0.01,0.025])
# Out:
# (-0.01, 0.025)

# %%
col2.high_periods
# Out:
# array([0.00065396, 0.00050364, 0.00050172, 0.00048276, 0.00046492,
#        0.0004848 , 0.00046304, 0.00048724, 0.00046296, 0.00047352,
#        0.0004696 , 0.0004644 , 0.00048004, 0.0004602 , 0.00048776,
#        0.00046372, 0.00048404, 0.00047652, 0.0004802 , 0.0004756 ,
#        0.0004748 , 0.0004706 , 0.00047792, 0.00048332, 0.00047576,
#        0.00048688, 0.00046772, 0.00049584, 0.00048196, 0.00046476,
#        0.0004582 , 0.00047512, 0.0004844 , 0.0004624 , 0.00048684,
#        0.0004772 , 0.00047516, 0.00047948, 0.00048104, 0.00047656,
#        0.00048028, 0.00047432, 0.00046644, 0.000478  , 0.00047644,
#        0.00046532, 0.0004796 , 0.00047328, 0.00047484, 0.0004742 ,
#        0.00048176, 0.000465  , 0.00048672, 0.00047924, 0.0004692 ,
#        0.00047924, 0.00049856, 0.00047508, 0.00047112, 0.00048652,
#        0.00046124, 0.00046608, 0.0004772 , 0.00047648, 0.00046272,
#        0.00047504, 0.00047924, 0.00045824, 0.00047656, 0.00047232,
# ...

# %%
plt.figure()
plt.plot(col2.high_periods[1:])

# %%
col0.
