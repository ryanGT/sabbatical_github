# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF

# %%
plt.rcParams['font.size'] = 14

# %%
ls *.csv
# Out:
# dc_motor_ol_1.csv   p_control_kp_3.csv
# p_control_kp_1.csv  p_control_kp_3_with_sat.csv

# %%
import glob

# %%
filenames = glob.glob("p_control_kp_*sat*.csv")

# %%
filenames
# Out:
# ['p_control_kp_3_with_sat.csv']

# %%
plt.figure()

for fn in filenames:
    data = np.loadtxt(fn,delimiter=',')
    nr,nc = data.shape
    t = data[:,0]
    v = data[:,1]
    if nc == 3:
        enc = data[:,2]
        plt.plot(t,v,t,enc)
    else:
        vsat = data[:,2]
        enc = data[:,3]
        plt.plot(t,v,t,vsat,t,enc)
    
plt.xlabel('Time (sec.)')
plt.ylabel('Signal Amp. (counts)')
plt.legend(['input voltage','encoder'])
