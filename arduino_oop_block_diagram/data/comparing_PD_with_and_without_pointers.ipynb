# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF

# %%
plt.rcParams['font.size'] = 14

# %%
ls *.csv
# Out:
# dc_motor_ol_1.csv   p_control_kp_3_with_sat.csv  PD_with_pointers_test1.csv
# p_control_kp_1.csv  pd_control_kp_3_kd_0_1.csv   PD_with_pointers_test2.csv
# p_control_kp_3.csv  PD_no_pointers_test1.csv

# %%
import glob

# %%
filenames = glob.glob("PD_*.csv")

# %%
filenames
# Out:
# ['PD_no_pointers_test1.csv',
#  'PD_with_pointers_test1.csv',
#  'PD_with_pointers_test2.csv']

# %%
plt.figure()

for fn in filenames[0:2]:
    data = np.loadtxt(fn,delimiter=',')
    nr,nc = data.shape
    t = data[:,0]
    enc = data[:,-1]
    #plt.figure()
    plt.plot(t,enc,label=fn)
    plt.xlabel('Time (sec.)')
    plt.ylabel('Signal Amp. (counts)')
    plt.legend(loc=4)
    plt.ylim([125,160])
    plt.xlim([500,1200])

# %%
fn = "pd_control_kp_3_kd_0_1.csv"

# %%
t
# Out:
# array([1.49000e+00, 3.53000e+00, 5.58000e+00, ..., 4.99331e+03,
#        4.99569e+03, 4.99807e+03])
