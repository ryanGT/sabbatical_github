# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
ls *.csv
# Out:
# data_from_printf.csv          data_from_serial_monitor.csv

# %%
data1 = np.loadtxt("data_from_printf.csv",delimiter=",")

# %%
n1 = data1[:,0]

# %%
enc1 = data1[:,-1]

# %%
data2 = np.loadtxt("data_from_serial_monitor.csv",delimiter=",")

# %%
n2 = data2[:,0]
enc2 = data2[:,-1]

# %%
plt.figure()
plt.plot(n1,enc1,n2,enc2,'--',linewidth=2)
