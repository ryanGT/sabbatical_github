# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF

# %%
plt.rcParams['font.size'] = 14

# %%
ls *.csv
# Out:
# line_follow_no_vib_suppress_two_sensors.csv
# line_follow_with_vib_suppress_test_1.csv

# %%
import glob

# %%
csvfiles = glob.glob("*.csv")

# %%
plt.figure()

for csvfile in csvfiles:
    data = np.loadtxt(csvfile,delimiter=',')
    t = data[:,0]
    enc = data[:,-2]
    plt.plot(t,enc)
plt.legend(['no vib. suppress','with vib. suppress'])
plt.xlabel('Time (ms)')
plt.ylabel('Pendulum Encoder (counts)')
# Out:
# Text(0, 0.5, 'Pendulum Encoder (counts)')
